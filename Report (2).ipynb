# %% [markdown]
# # Peer-graded Assignment: Capstone Project - Car accident severity (Week 2)

# %% [markdown]
# # Introduction

# %% [markdown]
# The costs of injuries due to traffic accidents have a great impact on the society. In recent years, reachers and data scientists have paid attention to factors that caused the traffic accidents. Applying data mining techniques to model traffic accident data records can help to understand the characteristics of driver's behaviour, roadway condition and weather condition that were causally connected with different injury severity

# %% [markdown]
# Local and State Highway and Road Departments as well Traffic Departments would be interested in accurate prediction of car collsions, for the advantage and business values of making the roads safer. Others who are interested in this model would be car manufactuers to see if they can make there vechiles even safer.

# %% [markdown]
# # Describe Data

# %% [markdown]
# The data was collected from Seattle police department, and our predictor will be 'SEVERITYCODE', which contains different levels of severity of an accident from 0 to 5 within the dataset. Attributes used to weigh the severity of an accident are 'WEATHER','ROADCOND',and'LIGHTCOND'.
#
# Severity codes are as following:

# %% [markdown]
# 0: Little to no Probability (Clear Conditions)
# 1: Very Low Probability — Chance or Property Damage
# 2: Low Probability — Chance of Injury
# 3: Mild Probability — Chance of Serious Injury
# 4: High Probability — Chance of Fatality

# %% [markdown]
# The data set has 37 independent variables and 194673 records. Many of the columns are object types,and some columns and rows have null values,
# which need to be preprocessed before any further processing.

# %% [markdown]
# ![data1.jpg](attachment:data1.jpg)![data1.jpg](attachment:8fa634ec-c622-4a5b-a62f-21b53e695b05.jpg)

# %% [markdown]
# ![data2.jpg](attachment:data2.jpg)![data2.jpg](attachment:79076ddc-9c7c-4677-a5fa-d9efbe485768.jpg)

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ![data3.jpg](attachment:data3.jpg)![data3.jpg](attachment:fff3c331-2593-40c2-b52b-da60fdb4f06b.jpg)

# %% [raw]
# We can see from above image that the original dataset is not ready for anaylsising  and it is imbalance, so we need to balance it first.

# %% [markdown]
# ![data4.jpg](attachment:data4.jpg)![data4.jpg](attachment:361499fe-8f4f-4230-aa3d-c92a1b72147f.jpg)

# %% [markdown]
# # Methodology

# %% [markdown]
# In this report, i am gping to use three models for machine learning:
# - K Nearest Neighbor(KNN)
# - Decision Tree
# - Logistic Regression

# %% [markdown]
# ## Define X & y before using the three models

# %% [markdown]
# ![Xy.jpg](attachment:XY.jpg)![Xy.jpg](attachment:db29d857-8408-4444-aeeb-d2eedd5af485.jpg)

# %% [markdown]
# ## Train/Test Split

# %% [markdown]
# Let's use 30% of our data for testing and 70% for training.

# %% [markdown]
# ![train.jpg](attachment:train.jpg)![train.jpg](attachment:dca72f27-3491-4a5e-ba62-30300dd6932d.jpg)

# %% [markdown]
# ## let's begin modelling and predictions

# %% [markdown]
# KNN -the k-nearest neighbors algorithm is a simple algorithm that stores all available cases and classifies new cases based on a similarity measure, so KNN will help us tp predict the severity code by finding the most similar points within k distamce.

# %% [markdown]
# ![knn.jpg](attachment:knn.jpg)![knn.jpg](attachment:80c76a4c-4075-4235-a018-4e37a09677e6.jpg)

# %% [markdown]
# Decision Tree belongs to the family of supervised learning algorithms.  The goal of using a Decision Tree is to create a training model that can use to predict the class or value of the target variable by learning simple decision rules inferred from training data. It will give us a layout of all possible outcomes so we can fully analyze the concequences of a decision. so that we could see different weather conditions from all possible outcomes.

# %% [markdown]
# ![decisiontree.jpg](attachment:decisiontree.jpg)

# %% [markdown]
# Logistic Regreesion is a predictive analysis. Logistic regression is used to describe data and to explain the relationship between one dependent binary variable and one or more nominal, ordinal, interval or ratio-level independent variables.Because our dataset only provides us with two severity code outcomes, our model will only predict one of those two classes. This makes our data binary, which is perfect to use with logistic regression.

# %% [markdown]
# ![logr.jpg](attachment:logr.jpg)![logr.jpg](attachment:2c7d55fd-96c2-43d0-a4d9-0f9dcdfa212d.jpg)

# %% [markdown]
# # Result

# %% [markdown]
# The final results of the model evaluations show as following:

# %% [markdown]
# ![result.jpg](attachment:result.jpg)![result.jpg](attachment:25b666d4-d8db-49d2-8295-5603f6b9814d.jpg)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on historical data from weather conditions pointing to certain classes, we can conclude that particular weather conditions have a somewhat impact on whether or not travel could result in property damage (class 1) or injury (class 2).
